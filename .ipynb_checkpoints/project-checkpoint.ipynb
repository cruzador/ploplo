# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx
import osmnx as ox
import os
import elevation
#from api_keys import google
google='AIzaSyBO_wxQmMhWAdSeqIPg04WJnrlXDH8Fbr8'
#import richdem as rd
from shapely.geometry import Point, LineString, Polygon
from descartes import PolygonPatch
import overpy

# %%
df=pd.read_csv('data.csv', sep=';')
dj=gpd.read_file('hahabge2015.shp')

# %%
dj=dj.to_crs({'init': 'epsg:2056'})

# %%
dj.crs
# Out:
# {'init': 'epsg:2056'}

# %%
df.columns[df.dtypes==object]
# Out:
# Index(['X', 'Y', 'bmi', 'ssb_if', 'bmi_aj', 'ssb_if_aj', 'age'], dtype='object')

# %%
for i in df.columns[df.dtypes==object]:
    df[i]=pd.to_numeric(df[i].apply(lambda x:x.replace(',','.')))

# %%
crs={'init' : 'espg:2056'}

# %%
geometry = [Point(xy) for xy in zip(df.X, df.Y)]

# %%
df=gpd.GeoDataFrame(df,geometry=geometry)

# %%
dj
# Out:
#           xmin      xmax      ymin      ymax   ID_1      RELI  X_KOORD  \
# 0     498800.0  498900.0  130300.0  130400.0  22217  49881303   498800
# 1     498900.0  499000.0  130300.0  130400.0  20091  49891303   498900
# 2     498700.0  498800.0  130000.0  130100.0  20829  49871300   498700
# 3     499100.0  499200.0  130000.0  130100.0  16253  49911300   499100
# 4     498500.0  498600.0  129800.0  129900.0  19904  49851298   498500
# ...        ...       ...       ...       ...    ...       ...      ...
# 7527  492000.0  492100.0  110800.0  110900.0  22040  49201108   492000
# 7528  499100.0  499200.0  110800.0  110900.0  16255  49911108   499100
# 7529  499200.0  499300.0  110800.0  110900.0  15564  49921108   499200
# 7530  491800.0  491900.0  110700.0  110800.0  16416  49181107   491800
# 7531  491500.0  491600.0  110400.0  110500.0  17120  49151104   491500
#
#       Y_KOORD  d_noisum  d_noimean  ...  n_noistdev  thermsum     thermmean  \
# 0      130300    4194.0  44.147368  ...    3.860303  399938.0  24996.125000
# 1      130300    4769.0  47.690000  ...    3.493651  300866.0  25072.166667
# 2      130000    5612.0  56.120000  ...    6.182322  224115.0  24901.666667
# 3      130000    4719.0  47.190000  ...    1.465435  232402.0  25822.444444
# 4      129800    5719.0  57.190000  ...    5.701324  225462.0  25051.333333
# ...       ...       ...        ...  ...         ...       ...           ...
# 7527   110800    3453.0  60.578947  ...    5.706638  409211.0  25575.687500
# 7528   110800    3559.0  35.590000  ...    4.624057  307416.0  25618.000000
# 7529   110800    2956.0  33.213483  ...    6.022891  308875.0  25739.583333
# 7530   110700    4184.0  58.929577  ...    6.953155  234515.0  26057.222222
# 7531   110400    4922.0  49.220000  ...    5.200490  303630.0  25302.500000
#
#       thermmedia  thermstdev   ndvi_sum  ndvi_mean  ndvi_media  ndvi_stdev  \
# 0        24986.5  190.109467  42.887409   0.428874    0.472898    0.107924
# 1        25067.0   79.700307  37.569557   0.375696    0.372390    0.046855
# 2        24889.0  184.727427  53.239057   0.532391    0.546810    0.086142
# 3        25875.0  114.630916  33.805875   0.338059    0.315955    0.067177
# 4        25041.0   32.533743  39.887415   0.398874    0.394372    0.058341
# ...          ...         ...        ...        ...         ...         ...
# 7527     25633.5  240.090535  27.808126   0.278081    0.263139    0.060496
# 7528     25623.5   54.569528  43.188598   0.431886    0.448357    0.066924
# 7529     25728.0   39.718716  32.701720   0.327017    0.327821    0.055055
# 7530     26064.0  145.287285  29.794923   0.297949    0.303661    0.035642
# 7531     25267.5  207.695891  38.634291   0.386343    0.358102    0.074931
#
#                                                geometry
# 0     POLYGON ((2498800.000 1130400.000, 2498900.000...
# 1     POLYGON ((2498900.000 1130400.000, 2499000.000...
# 2     POLYGON ((2498700.000 1130100.000, 2498800.000...
# 3     POLYGON ((2499100.000 1130100.000, 2499200.000...
# 4     POLYGON ((2498500.000 1129900.000, 2498600.000...
# ...                                                 ...
# 7527  POLYGON ((2492000.000 1110900.000, 2492100.000...
# 7528  POLYGON ((2499100.000 1110900.000, 2499200.000...
# 7529  POLYGON ((2499200.000 1110900.000, 2499300.000...
# 7530  POLYGON ((2491800.000 1110800.000, 2491900.000...
# 7531  POLYGON ((2491500.000 1110500.000, 2491600.000...
#
# [7532 rows x 25 columns]

# %%
fig,ax=plt.subplots(figsize=(10,10))
df.plot(ax=ax,column='bmi_aj',scheme='quantiles',alpha=0.8,legend=True)
dj.plot(ax=ax,column='ndvi_mean',scheme='quantiles', k=3)

# %%
fig,ax=plt.subplots(figsize=(10,10))
dj.plot(ax=ax,column='ndvi_mean',scheme='quantiles', k=3)

# %%
dj.shape
# Out:
# (7532, 25)

# %%
a = gpd.sjoin(df,dj,op='intersects')
# Out:
# C:\Users\hugo\Anaconda3\envs\geoviz\lib\site-packages\geopandas\tools\sjoin.py:61: UserWarning: CRS of frames being joined does not match!(None != {'init': 'epsg:2056'})
#   "(%s != %s)" % (left_df.crs, right_df.crs)

# %%
np.shape(a)
# Out:
# (15249, 37)

# %%
a
# Out:
#                 X           Y  yy_surv   bmi    ssb_if     bmi_aj  ssb_if_aj  \
# 0      2502550.35  1116295.23     2010  15.0  1.000000  39.346334   0.946335
# 1      2498334.97  1118323.10     2001  16.0  0.000000  40.343282   0.000000
# 578    2498334.97  1118323.10     1997  23.0  0.000000  47.408120   0.008120
# 724    2498356.84  1118316.17     2008  24.0  0.089286  48.319055   0.008341
# 3930   2498303.70  1118348.31     1998  21.6  0.000000  45.930462   0.000000
# ...           ...         ...      ...   ...       ...        ...        ...
# 15348  2498431.10  1118783.92     2002  34.5  0.000000  58.859940   0.000000
# 15366  2499402.16  1127014.56     2013  35.1  0.214286  59.460377   0.174663
# 15389  2494685.06  1118267.82     2014  36.4  0.000000  60.759106   0.000000
# 15396  2500026.65  1113067.01     2014  36.8  0.214286  61.221849   0.236135
# 15408  2506017.58  1125199.83     2008  37.5  0.035714  61.826868   0.000000
#
#         age  med_inc2009  nationality  ...  n_noimedia n_noistdev  thermsum  \
# 0      43.7       105981            1  ...        44.0   6.062763  305036.0
# 1      43.2        63757            1  ...        35.0  13.416840  238626.0
# 578    69.5        63757            1  ...        35.0  13.416840  238626.0
# 724    41.7        63757            1  ...        35.0  13.416840  238626.0
# 3930   38.0        63757            1  ...        35.0  13.416840  238626.0
# ...     ...          ...          ...  ...         ...        ...       ...
# 15348  53.7        68987            0  ...        36.0   3.806573  236053.0
# 15366  49.9        77165            1  ...        34.0   1.799556  218000.0
# 15389  53.0        89685            0  ...        43.0   1.664332  314760.0
# 15396  74.6        90585            1  ...        31.0   2.973819  310759.0
# 15408  44.5        84890            1  ...        38.0   4.898275  304019.0
#
#           thermmean  thermmedia  thermstdev   ndvi_sum  ndvi_mean  ndvi_media  \
# 0      25419.666667     25394.5   89.041501  45.798232   0.457982    0.495619
# 1      26514.000000     26508.0   44.899889  17.597171   0.175972    0.161140
# 578    26514.000000     26508.0   44.899889  17.597171   0.175972    0.161140
# 724    26514.000000     26508.0   44.899889  17.597171   0.175972    0.161140
# 3930   26514.000000     26508.0   44.899889  17.597171   0.175972    0.161140
# ...             ...         ...         ...        ...        ...         ...
# 15348  26228.111111     26224.0   60.235546  22.487600   0.224876    0.223172
# 15366  24222.222222     24226.0   57.330965  46.506022   0.465060    0.470883
# 15389  26230.000000     26257.0  162.507436  25.966030   0.259660    0.265537
# 15396  25896.583333     25832.0  233.280396  32.184866   0.321849    0.336476
# 15408  25334.916667     25342.0   73.276256  41.293264   0.412933    0.415467
#
#        ndvi_stdev
# 0        0.085945
# 1        0.062273
# 578      0.062273
# 724      0.062273
# 3930     0.062273
# ...           ...
# 15348    0.067179
# 15366    0.032198
# 15389    0.046206
# 15396    0.075391
# 15408    0.053104
#
# [15249 rows x 37 columns]

# %%
# Out:
#                 X           Y  yy_surv   bmi    ssb_if     bmi_aj  ssb_if_aj  \
# 0      2502550.35  1116295.23     2010  15.0  1.000000  39.346334   0.946335
# 1      2498334.97  1118323.10     2001  16.0  0.000000  40.343282   0.000000
# 2      2506819.72  1122397.48     2002  16.0  0.500000  40.302807   0.402808
# 3      2497640.31  1118823.22     1997  17.0  0.500000  41.326112   0.426112
# 4      2498497.97  1113172.89     2012  17.0  1.000000  41.299859   0.899859
# ...           ...         ...      ...   ...       ...        ...        ...
# 15418  2504557.42  1116565.46     2014  39.3  0.214286  63.634467   0.148753
# 15419  2498481.50  1120251.90     2000  40.5  0.000000  64.881118   0.000000
# 15420  2501348.12  1116601.06     1999  41.5  0.214286  65.866576   0.180862
# 15421  2498954.20  1117481.61     2012  46.5  0.000000  70.884895   0.000000
# 15422  2501494.58  1127166.13     2002  59.5  0.000000  83.868477   0.000000
#
#         age  med_inc2009  nationality  sex                         geometry
# 0      43.7       105981            1    0  POINT (2502550.350 1116295.230)
# 1      43.2        63757            1    0  POINT (2498334.970 1118323.100)
# 2      34.7        87194            1    1  POINT (2506819.720 1122397.480)
# 3      36.2        65779            1    0  POINT (2497640.310 1118823.220)
# 4      24.6       120185            1    0  POINT (2498497.970 1113172.890)
# ...     ...          ...          ...  ...                              ...
# 15418  35.2        59853            0    0  POINT (2504557.420 1116565.460)
# 15419  58.4        72179            1    0  POINT (2498481.500 1120251.900)
# 15420  56.0        91392            0    1  POINT (2501348.120 1116601.060)
# 15421  58.4        54119            1    0  POINT (2498954.200 1117481.610)
# 15422  61.5        77893            1    1  POINT (2501494.580 1127166.130)
#
# [15423 rows x 12 columns]

# %%
np.shape(dj)
# Out:
# (7532, 25)

# %%
np.shape(df)
# Out:
# (15423, 12)

# %%
buildings = ox.buildings_from_place('gva')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d12d4fda61f6> in <module>
# ----> 1 buildings = ox.buildings_from_place('gva')
#
# AttributeError: module 'osmnx' has no attribute 'buildings_from_place'

# %%
restaurants = ox.pois_from_place('gva', amenities=['restaurant'],)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\connection.py in connect(self)
#     333         # Add certificate verification
# --> 334         conn = self._new_conn()
#     335         hostname = self.host
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e
#     170             )
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x00000279420E4988>: Failed to establish a new connection: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~\Anaconda3\envs\geoviz\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?format=json&limit=1&dedupe=0&polygon_geojson=1&q=gva (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000279420E4988>: Failed to establish a new connection: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-6-75c6ae54f882> in <module>
# ----> 1 restaurants = ox.pois_from_place('gva', amenities=['restaurant'])
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\osmnx\pois.py in pois_from_place(place, amenities, which_result)
#     455     """
#     456
# --> 457     city = gdf_from_place(place, which_result=which_result)
#     458     polygon = city['geometry'].iloc[0]
#     459     return create_poi_gdf(polygon=polygon, amenities=amenities)
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\osmnx\core.py in gdf_from_place(query, gdf_name, which_result, buffer_dist)
#     446
#     447     # get the data from OSM
# --> 448     data = osm_polygon_download(query, limit=which_result)
#     449     if len(data) >= which_result:
#     450
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\osmnx\core.py in osm_polygon_download(query, limit, polygon_geojson)
#     414
#     415     # request the URL, return the JSON
# --> 416     response_json = nominatim_request(params=params, timeout=30)
#     417     return response_json
#     418
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\osmnx\core.py in nominatim_request(params, type, pause_duration, timeout, error_pause_duration)
#     270         start_time = time.time()
#     271         log('Requesting {} with timeout={}'.format(prepared_url, timeout))
# --> 272         response = requests.get(url, params=params, timeout=timeout, headers=get_http_headers())
#     273
#     274         # get the response size and the domain, log result
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\geoviz\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?format=json&limit=1&dedupe=0&polygon_geojson=1&q=gva (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x00000279420E4988>: Failed to establish a new connection: [WinError 10060] Une tentative de connexion a échoué car le parti connecté n’a pas répondu convenablement au-delà d’une certaine durée ou une connexion établie a échoué car l’hôte de connexion n’a pas répondu'))

# %%
api = overpy.Overpass()
result = api.query("""node["name"="GVA"];out body;""")

# %%
api

# %%
result.get_area()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-cdd5ccffc597> in <module>
# ----> 1 result.get_area()
#
# TypeError: get_area() missing 1 required positional argument: 'area_id'

# %%
result.get_node_ids()
# Out:
# [4245166752]
